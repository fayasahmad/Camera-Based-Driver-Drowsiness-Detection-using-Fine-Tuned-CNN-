# %%
# %pip install tensorflow

# %%
import os, glob, zipfile, json, tensorflow as tf
print("TF:", tf.__version__)
# Out:
# TF: 2.20.0

# %%
#fetch from Google Drive, extract, and locate `mrleyedataset`
# %pip -q install gdown

import os, zipfile
from glob import glob
import gdown

FILE_ID = "1Zr_AtNJsZ1a4QNipHvAGddCc7XMUJUUX"   # <-- change if needed
OUT_ZIP = "/content/archive.zip"
DATA_ROOT = "/content/data"
TARGET_NAME = "mrleyedataset"
EXTRACT_DIR = os.path.join(DATA_ROOT, TARGET_NAME)

gdown.download(f"https://drive.google.com/uc?id={FILE_ID}", OUT_ZIP, quiet=False)
os.makedirs(DATA_ROOT, exist_ok=True)

with zipfile.ZipFile(OUT_ZIP, "r") as zf:
    zf.extractall(DATA_ROOT)

if not os.path.isdir(EXTRACT_DIR):
    candidates = [p for p in glob(os.path.join(DATA_ROOT, "**"), recursive=True)
                  if os.path.isdir(p) and os.path.basename(p).lower() == TARGET_NAME]
    assert candidates, "Couldn't find 'mrleyedataset' in the ZIP."
    EXTRACT_DIR = candidates[0]

print("Dataset root:", EXTRACT_DIR)
print("Subdirs:", os.listdir(EXTRACT_DIR))
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Zr_AtNJsZ1a4QNipHvAGddCc7XMUJUUX
# From (redirected): https://drive.google.com/uc?id=1Zr_AtNJsZ1a4QNipHvAGddCc7XMUJUUX&confirm=t&uuid=cd57338c-2ac4-4693-9c1a-d825260f31f4
# To: /content/archive.zip
# 100%|██████████| 346M/346M [00:01<00:00, 267MB/s]
# Dataset root: /content/data/mrleyedataset
# Subdirs: ['Close-Eyes', 'Open-Eyes']

# %%
IMG_SIZE, BATCH, SEED = 160, 32, 1337
VAL_SPLIT = 0.10
EPOCHS_WARMUP, EPOCHS_FINETUNE = 5, 10

from tensorflow.keras.utils import image_dataset_from_directory
train_ds = image_dataset_from_directory(EXTRACT_DIR, label_mode="binary",
    validation_split=VAL_SPLIT, subset="training", seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH, shuffle=True)
val_ds = image_dataset_from_directory(EXTRACT_DIR, label_mode="binary",
    validation_split=VAL_SPLIT, subset="validation", seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH, shuffle=True)

AUTOTUNE = tf.data.AUTOTUNE
train_ds, val_ds = train_ds.cache().prefetch(AUTOTUNE), val_ds.cache().prefetch(AUTOTUNE)

from tensorflow.keras import layers
augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.05),
    layers.RandomContrast(0.2),
])
# Out:
# Found 84898 files belonging to 2 classes.
# Using 76409 files for training.
# Found 84898 files belonging to 2 classes.
# Using 8489 files for validation.

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras import Model

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = augment(inputs)
x = layers.Lambda(preprocess_input)(x)
base = MobileNetV2(include_top=False, weights="imagenet", input_shape=(IMG_SIZE, IMG_SIZE, 3))
base.trainable = False
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="binary_crossentropy",
              metrics=[tf.keras.metrics.BinaryAccuracy(name="acc"),
                       tf.keras.metrics.Precision(name="prec"),
                       tf.keras.metrics.Recall(name="rec")])

cb_es = tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True, monitor="val_acc")
model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_WARMUP, callbacks=[cb_es])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 326s 134ms/step - acc: 0.9443 - loss: 0.1443 - prec: 0.9534 - rec: 0.9353 - val_acc: 0.9714 - val_loss: 0.0756 - val_prec: 0.9709 - val_rec: 0.9725
# Epoch 2/5
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 318s 133ms/step - acc: 0.9656 - loss: 0.0923 - prec: 0.9696 - rec: 0.9621 - val_acc: 0.9737 - val_loss: 0.0676 - val_prec: 0.9809 - val_rec: 0.9669
# Epoch 3/5
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 321s 134ms/step - acc: 0.9691 - loss: 0.0838 - prec: 0.9716 - rec: 0.9671 - val_acc: 0.9741 - val_loss: 0.0647 - val_prec: 0.9818 - val_rec: 0.9667
# Epoch 4/5
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 321s 135ms/step - acc: 0.9705 - loss: 0.0780 - prec: 0.9733 - rec: 0.9682 - val_acc: 0.9756 - val_loss: 0.0620 - val_prec: 0.9780 - val_rec: 0.9737
# Epoch 5/5
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 322s 135ms/step - acc: 0.9719 - loss: 0.0748 - prec: 0.9734 - rec: 0.9708 - val_acc: 0.9783 - val_loss: 0.0596 - val_prec: 0.9766 - val_rec: 0.9807

# %%
# fine-tune
base.trainable = True
for l in base.layers[:-40]:
    l.trainable = False
model.compile(optimizer=tf.keras.optimizers.Adam(5e-5),
              loss="binary_crossentropy",
              metrics=[tf.keras.metrics.BinaryAccuracy(name="acc"),
                       tf.keras.metrics.Precision(name="prec"),
                       tf.keras.metrics.Recall(name="rec")])
model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FINETUNE, callbacks=[cb_es])

print("Eval:")
model.evaluate(val_ds)
# Out:
# Epoch 1/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 451s 185ms/step - acc: 0.9533 - loss: 0.1567 - prec: 0.9479 - rec: 0.9617 - val_acc: 0.9627 - val_loss: 0.1165 - val_prec: 0.9502 - val_rec: 0.9774
# Epoch 2/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 444s 186ms/step - acc: 0.9820 - loss: 0.0507 - prec: 0.9803 - rec: 0.9842 - val_acc: 0.9530 - val_loss: 0.1166 - val_prec: 0.9942 - val_rec: 0.9124
# Epoch 3/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 442s 185ms/step - acc: 0.9856 - loss: 0.0401 - prec: 0.9831 - rec: 0.9884 - val_acc: 0.9697 - val_loss: 0.0767 - val_prec: 0.9572 - val_rec: 0.9842
# Epoch 4/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 441s 185ms/step - acc: 0.9869 - loss: 0.0344 - prec: 0.9847 - rec: 0.9895 - val_acc: 0.9782 - val_loss: 0.0777 - val_prec: 0.9916 - val_rec: 0.9651
# Epoch 5/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 445s 186ms/step - acc: 0.9885 - loss: 0.0323 - prec: 0.9866 - rec: 0.9906 - val_acc: 0.9868 - val_loss: 0.0354 - val_prec: 0.9820 - val_rec: 0.9921
# Epoch 6/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 444s 186ms/step - acc: 0.9899 - loss: 0.0277 - prec: 0.9872 - rec: 0.9928 - val_acc: 0.9549 - val_loss: 0.1657 - val_prec: 0.9977 - val_rec: 0.9129
# Epoch 7/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 446s 187ms/step - acc: 0.9908 - loss: 0.0244 - prec: 0.9888 - rec: 0.9931 - val_acc: 0.9706 - val_loss: 0.1463 - val_prec: 0.9953 - val_rec: 0.9462
# Epoch 8/10
# 2388/2388 ━━━━━━━━━━━━━━━━━━━━ 412s 172ms/step - acc: 0.9908 - loss: 0.0238 - prec: 0.9887 - rec: 0.9932 - val_acc: 0.9479 - val_loss: 0.2348 - val_prec: 0.9964 - val_rec: 0.9003
# Eval:
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - acc: 0.9858 - loss: 0.0382 - prec: 0.9817 - rec: 0.9906
# [0.035393550992012024,
#  0.9868064522743225,
#  0.9820193648338318,
#  0.9920819997787476]

# %%
# export for VS Code inference
import os, json # Import json here as it's used later in the cell

EXPORT_DIR = "./mobilenetv2_eye_state"
os.makedirs(EXPORT_DIR, exist_ok=True)
model.save(os.path.join(EXPORT_DIR, "model.keras")) # Save in Keras native format
model.export(os.path.join(EXPORT_DIR, "savedmodel")) # Export in SavedModel format

class_names = dict(enumerate(sorted(os.listdir(EXTRACT_DIR))))
with open(os.path.join(EXPORT_DIR, "labels.json"), "w") as f:
    json.dump(class_names, f, indent=2)
# Out:
# Saved artifact at './mobilenetv2_eye_state/savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   135770710960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710961296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710961680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710964368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710965904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710965136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028277840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565656656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565656848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699073104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710964944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699075216: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Optional TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
open(os.path.join(EXPORT_DIR, "model.tflite"), "wb").write(converter.convert())
print("Saved to", EXPORT_DIR)
# Out:
# Saved artifact at '/tmp/tmpxz44jr00'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   135770710964368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710965904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710965136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028277840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028279760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028280144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028283408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028281104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028287632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028290128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028289360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770028293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564788880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564789072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564790992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564791952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564792912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564794832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564795792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564796752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564797712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564798672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564799632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564800592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564802512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564803472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770564804432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565656656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565656848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565658384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699073104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770565672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770710964944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699072720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135770699075216: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved to ./mobilenetv2_eye_state

# %%
# just run:
model.evaluate(val_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-341289943.py in <cell line: 0>()
#       1 # just run:
# ----> 2 model.evaluate(val_ds)
#
# NameError: name 'model' is not defined
